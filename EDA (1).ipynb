# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('BIKE DETAILS.csv')

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
df.selling_price.value_counts()
# Out:
# selling_price
# 25000    77
# 35000    66
# 50000    63
# 40000    63
# 30000    62
#          ..
# 39000     1
# 83299     1
# 14700     1
# 19000     1
# 31000     1
# Name: count, Length: 130, dtype: int64

# %%
#What is the range of selling prices in the dataset?
df['selling_price'].min()
# Out:
# 5000

# %%
df['selling_price'].max()
# Out:
# 760000

# %%
#2.What is the median selling price for bikes in the dataset?
df['selling_price'].median()
# Out:
# 45000.0

# %%
#3.What is the most common seller type?
df['seller_type'].value_counts()
# Out:
# seller_type
# Individual    1055
# Dealer           6
# Name: count, dtype: int64

# %%
#4. How many bikes have driven more than 50,000 kilometers?
df[df['km_driven']>50000]
# Out:
#                                name  selling_price  year seller_type  \
# 5                  Honda CB Twister          18000  2010  Individual
# 15    Suzuki Access 125 [2007-2016]          25000  2012  Individual
# 20             Hero Passion Pro 110          15000  2008  Individual
# 31          Yamaha FZ S [2012-2016]          38000  2013  Individual
# 43                Hero Passion XPro          28000  2012  Individual
# ...                             ...            ...   ...         ...
# 1049            Hero Super Splendor          20000  2007  Individual
# 1050               Bajaj Pulsar 150          20000  2010  Individual
# 1056                      Activa 3g          17000  2010  Individual
# 1059                 Honda CB Shine          12000  2009  Individual
# 1060               Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# 5     1st owner      60000            53857.0
# ...

# %%
df.isna().sum()
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %%
#5. What is the average km_driven value for each ownership type?
df.groupby('owner')['km_driven'].mean()
# Out:
# owner
# 1st owner     32816.583333
# 2nd owner     39288.991870
# 3rd owner     33292.181818
# 4th owner    311500.000000
# Name: km_driven, dtype: float64

# %%
#6. What proportion of bikes are from the year 2015 or older?
df[df['year']>=2015]
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 6                    Honda CB Hornet 160R          78500  2018  Individual
# ...                                   ...            ...   ...         ...
# 1043                   Bajaj Discover 100          27000  2015  Individual
# 1047                     Honda CB twister          25000  2015  Individual
# 1048                         Hero Glamour          25000  2015  Individual
# 1053                   Hero  Ignitor Disc          20000  2015  Individual
# 1055                        Bajaj  ct 100          18000  2017  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
#7. What is the trend of missing values across the dataset?
df.isna().sum()
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %%
#8. What is the highest ex_showroom_price recorded, and for which bike
df[df['ex_showroom_price']==df['ex_showroom_price'].max()]
# Out:
#                            name  selling_price  year seller_type      owner  \
# 134  Harley-Davidson Street Bob         750000  2013  Individual  2nd owner
#
#      km_driven  ex_showroom_price  age  average_price
# 134      12000          1278000.0   12   51136.986301

# %%
df.ex_showroom_price.value_counts()
# Out:
# ex_showroom_price
# 50267.0     23
# 85011.0     20
# 54605.0     15
# 74295.0     14
# 78712.0     12
#             ..
# 129662.0     1
# 66697.0      1
# 69983.0      1
# 76632.0      1
# 32000.0      1
# Name: count, Length: 230, dtype: int64

# %%
df['ex_showroom_price'].max()
# Out:
# 1278000.0

# %%
#10. What is the total number of bikes listed by each seller type
df['seller_type'].value_counts()
# Out:
# seller_type
# Individual    1055
# Dealer           6
# Name: count, dtype: int64

# %%
#11. What is the relationship between selling_price and km_driven for first-owner bikes
df[df['owner']=='1st owner'].groupby('owner')[['selling_price','km_driven']].mean()
# Out:
#            selling_price     km_driven
# owner
# 1st owner   60022.813853  32816.583333

# %%
df
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1056                            Activa 3g          17000  2010  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
#12. Identify and remove outliers in the km_driven column using the IQR method
df.km_driven.value_counts()
# Out:
# km_driven
# 20000     39
# 40000     38
# 50000     37
# 25000     31
# 30000     28
#           ..
# 33200      1
# 646000     1
# 3909       1
# 7672       1
# 92233      1
# Name: count, Length: 304, dtype: int64

# %%
Q1 = 25/100*304+1
Q3 = 75/100*304+1

# %%
Q1
# Out:
# 77.0

# %%
Q3
# Out:
# 229.0

# %%
IQR = Q3-Q1

# %%
IQR
# Out:
# 152.0

# %%
lower_fence = Q1-1.5*152

# %%
lower_fence
# Out:
# -151.0

# %%
higher_fence = Q3+1.5*IQR

# %%
higher_fence
# Out:
# 457.0

# %%
data=df['km_driven']
outliers = []
def detect_outliers(data):
    threshold = 3
    mean = np.mean(data)
    std = np.std(data)

    for i in data:
        z_score = (i-mean)/std
        if np.abs(z_score)>threshold:
            outliers.append(i)
    return outliers

# %%
outliers = detect_outliers(data)

# %%
outliers
# Out:
# [500000,
#  646000,
#  585659,
#  340000,
#  880000,
#  240000,
#  345000,
#  450000,
#  213000,
#  500000]

# %%
df[~df['km_driven'].isin(outliers)]
# Out:
#                                      name  selling_price  year seller_type  \
# 0               Royal Enfield Classic 350         175000  2019  Individual
# 1                               Honda Dio          45000  2017  Individual
# 2     Royal Enfield Classic Gunmetal Grey         150000  2018  Individual
# 3       Yamaha Fazer FI V 2.0 [2016-2018]          65000  2015  Individual
# 4                   Yamaha SZ [2013-2014]          20000  2011  Individual
# ...                                   ...            ...   ...         ...
# 1055                        Bajaj  ct 100          18000  2017  Individual
# 1057                     Honda CB twister          16000  2012  Individual
# 1058                   Bajaj Discover 125          15000  2013  Individual
# 1059                       Honda CB Shine          12000  2009  Individual
# 1060                     Bajaj Pulsar 150          10000  2008  Individual
#
#           owner  km_driven  ex_showroom_price
# ...

# %%
#12.Perform a bivariate analysis to visualize the relationship between year and selling_price?
fig = plt.figure(figsize=(15,10))
sns.barplot(x='year',y='selling_price',data=df)
plt.show()

# %%
#13. What is the average depreciation in selling price based on the bike's age (current year - manufacturing year)?
df['age'] = 2025-df['year']
df.groupby('age')['selling_price'].mean()
# Out:
# age
# 5     183333.333333
# 6     119689.511628
# 7      87660.374046
# 8      78894.736842
# 9      58469.018692
# 10     56500.000000
# 11     48668.131868
# 12     51136.986301
# 13     35748.400000
# 14     35655.721311
# 15     31793.333333
# 16     22267.857143
# 17     34289.285714
# 18     24927.586207
# 19     23380.000000
# 20     16978.571429
# 21     15100.000000
# 22      8000.000000
# 23     20666.666667
# 24     40000.000000
# 25     20833.333333
# 26     15000.000000
# 27     28333.333333
# 28     17500.000000
# 30    150000.000000
# 32    130000.000000
# 34      6000.000000
# 37     20000.000000
# Name: selling_price, dtype: float64

# %%
#14. Which bike names are priced significantly above the average price for their manufacturing year?
average_price = df.groupby('year')['selling_price'].mean()
df['average_price'] = df['year'].map(average_price)
df_above_avg = df[df['selling_price'] > 1.5 * df['average_price']]
print(df_above_avg[['name', 'year', 'selling_price', 'average_price']])
# Out:
#                                      name  year  selling_price  average_price
# 2     Royal Enfield Classic Gunmetal Grey  2018         150000   87660.374046
# 7    Royal Enfield Bullet 350 [2007-2011]  2008         180000   34289.285714
# 13                          Yamaha YZF R3  2019         365000  119689.511628
# 18    Royal Enfield Classic Gunmetal Grey  2018         150000   87660.374046
# 23                          Jawa Standard  2019         180000  119689.511628
# ..                                    ...   ...            ...            ...
# 979             Royal Enfield Thunder 500  2015         105000   56500.000000
# 981             Royal Enfield Thunder 350  2013         105000   51136.986301
# 983             Royal Enfield Classic 350  2015         100000   56500.000000
# 984             Royal Enfield Classic 500  2014          95000   48668.131868
# 985             Royal Enfield Classic 500  2011          90000   35655.721311
#
# [157 rows x 4 columns]

# %%
#15.Develop a correlation matrix for numeric columns and visualize it using a heatmap.
numeric_columns = df.select_dtypes(include=['int64', 'float64'])
correlation_matrix = numeric_columns.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #Car Sales EDA

# %%
df = pd.read_csv('Car Sale.csv')

# %%
df
# Out:
# Empty DataFrame
# Columns: [Car_id, Date, Customer Name, Gender, Annual Income, Dealer_Name, Company, Model, Engine, Transmission, Color, Price ($), Dealer_No , Body Style, Phone, Dealer_Region, Date of Sale, Month]
# Index: []

# %%
df.shape
# Out:
# (23906, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         23906 non-null  object
#  1   Date           23906 non-null  object
#  2   Customer Name  23905 non-null  object
#  3   Gender         23906 non-null  object
#  4   Annual Income  23906 non-null  int64
#  5   Dealer_Name    23906 non-null  object
#  6   Company        23906 non-null  object
#  7   Model          23906 non-null  object
#  8   Engine         23906 non-null  object
#  9   Transmission   23906 non-null  object
#  10  Color          23906 non-null  object
#  11  Price ($)      23906 non-null  int64
#  12  Dealer_No      23906 non-null  object
#  13  Body Style     23906 non-null  object
#  14  Phone          23906 non-null  int64
#  15  Dealer_Region  23906 non-null  object
# dtypes: int64(3), object(13)
# memory usage: 2.9+ MB

# %%
#1. What is the average selling price of cars for each dealer, and how does it compare across different dealers?
df.groupby('Dealer_Name')['Price ($)'].mean()
# Out:
# Dealer_Name
# Buddy Storbeck's Diesel Service Inc                27217.261563
# C & M Motors Inc                                   28111.755200
# Capitol KIA                                        28189.703822
# Chrysler Plymouth                                  27555.526400
# Chrysler of Tri-Cities                             28123.091054
# Classic Chevy                                      28602.014446
# Clay Johnson Auto Sales                            27816.027113
# Diehl Motor CO Inc                                 27993.929487
# Enterprise Rent A Car                              28312.580800
# Gartner Buick Hyundai Saab                         28247.621019
# Hatfield Volkswagen                                27853.712242
# Iceberg Rentals                                    28522.958533
# McKinney Dodge Chrysler Jeep                       27684.096979
# Motor Vehicle Branch Office                        27956.739617
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Dealer_Name',y='Price ($)',data=df,palette = 'viridis')
plt.xticks(rotation=90)
plt.show()

# %%
#Insights
#Most dealers have car prices around $26,000 to $30,000.
#The first few dealers on the left, such as Buddy Strobek's Diesel Service Inc,c & m motors slightly lower prices than others

# %%
#2. Which car brand (Company) has the highest variation in prices, and what does this tell us about the pricing trends?
price = df.groupby('Company')['Price ($)'].std()
highest_variation = price.idxmax()
print(f"The car brand with the highest variation in prices is {highest_variation}.")
# Out:
# The car brand with the highest variation in prices is Lincoln.

# %%
#. 3What is the distribution of car prices for each transmission type, and how do the interquartile ranges compare?
plt.figure(figsize=(10,6))
sns.boxplot(x='Transmission',y='Price ($)',data=df,palette = 'viridis')
plt.show()

# %%
#Insights
#Automatic Cars Have a Wider Price Range
# Manual Cars Are More Consistently Priced
#The boxplot shows several outliers in the automatic transmission category

# %%
#4.What is the distribution of car prices across different regions?
plt.figure(figsize=(10,6))
sns.boxplot(x='Dealer_Region',y='Price ($)',data=df,palette = 'viridis')
plt.show()

# %%
#5. What is the distribution of cars based on body styles?
plt.figure(figsize=(10,6))
sns.countplot(x='Body Style',data=df,palette = 'viridis')
plt.show()

# %%
#Insights
#SUV showing a growing market share.
#They are affordable, fuel-efficient, and popular for daily use.

# %%
#6. How does the average selling price of cars vary by customer gender and annual income?
plt.figure(figsize=(12,6))
sns.barplot(x='Gender', y='Price ($)', hue='Annual Income', data=df, palette='viridis')
plt.title("Average Selling Price of Cars by Gender & Annual Income")
plt.xlabel("Gender")
plt.ylabel("Average Price ($)")
plt.legend(title="Annual Income")
plt.show()

# %%
#7. What is the distribution of car prices by region, and how does the number of cars sold vary by region?
plt.figure(figsize=(10,6))
sns.boxplot(x='Dealer_Region',y = 'Price ($)' ,data=df,palette = 'viridis')
plt.xlabel("Region", fontsize=12)
plt.ylabel("Car Price ($)", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x='Dealer_Region',data=df,palette = 'viridis')
plt.xlabel("Region", fontsize=12)
plt.ylabel("Number of Cars Sold", fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
#8. How does the average car price differ between cars with different engine sizes?
plt.figure(figsize=(10,6))
sns.barplot(x='Engine',y='Price ($)',data=df,palette = 'viridis')
plt.show()

# %%
#Insights
#slightly diffrence in cars engine prices

# %%
#9.  How do car prices vary based on the customer’s annual income bracket?
plt.figure(figsize=(20,15))
sns.barplot(x='Annual Income',y='Price ($)',data=df,palette = 'viridis')
plt.show()

# %%
#10. What are the top 5 car models with the highest number of sales, and how does their price distribution look?
top_models = df.groupby('Model')['Price ($)'].count().nlargest(5)
top_models_data = df[df['Model'].isin(top_models.index)]
print("Top 5 Car Models with Highest Sales:\n")
print(top_models)
plt.figure(figsize=(10,6))
sns.boxplot(x='Model',y='Price ($)',data=top_models_data,palette = 'viridis')
plt.show()
# Out:
# Top 5 Car Models with Highest Sales:
#
# Model
# Diamante      418
# Prizm         411
# Silhouette    411
# Passat        391
# Ram Pickup    383
# Name: Price ($), dtype: int64

# %%
#11.How does car price vary with engine size across different car colors, and which colors have the highest price variation
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.scatterplot(x='Engine', y='Price ($)', hue='Color', data=df, palette='viridis')
plt.title("Car Price vs. Engine Size Across Different Colors", fontsize=14)
plt.xlabel("Engine Size (CC)", fontsize=12)
plt.ylabel("Car Price ($)", fontsize=12)
plt.legend(title="Car Color")

plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='Color', y='Price ($)', data=df, palette='viridis')
plt.title("Car Price Distribution Across Different Colors", fontsize=14)
plt.xlabel("Car Color", fontsize=12)
plt.ylabel("Price ($)", fontsize=12)
plt.xticks(rotation=45)

plt.show()

# %%
# Calculate price variation
color_price_variation = df.groupby('Color')['Price ($)'].std().sort_values(ascending=False)
print("Top 5 Colors with Highest Price Variation:\n")
print(color_price_variation.head(5))
# Out:
# Top 5 Colors with Highest Price Variation:
#
# Color
# Red           15519.360962
# Black         15286.065976
# Pale White    14077.346859
# Name: Price ($), dtype: float64

# %%
#12. Is there any seasonal trend in car sales based on the date of sale?
df['Date of Sale'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date of Sale'].dt.month
monthly_sales = df.groupby('Month').size()
plt.figure(figsize=(10,6))
sns.barplot(x=monthly_sales.index, y=monthly_sales.values, palette='viridis')
# Out:
# <Axes: xlabel='Month'>

# %%
monthly_sales
# Out:
# Month
# 1      790
# 2      735
# 3     1535
# 4     1655
# 5     1895
# 6     1715
# 7     1725
# 8     1705
# 9     3305
# 10    1830
# 11    3470
# 12    3546
# dtype: int64

# %%
#13.How does the car price distribution change when considering different combinations of body style and transmission type?
plt.figure(figsize=(12,6))
sns.boxplot(x='Body Style', y='Price ($)', hue='Transmission', data=df, palette='viridis')
# Out:
# <Axes: xlabel='Body Style', ylabel='Price ($)'>

# %%
df['Price ($)'].isna().sum()
# Out:
# 0

# %%
#14. What is the correlation between car price, engine size, and annual income of customers, and how do these features interact?
df['Price ($)'] = pd.to_numeric(df['Price ($)'], errors='coerce')
if df['Engine'].dtype == 'object':
    df['Engine'] = df['Engine'].str.extract('(\d+)')
df['Engine'] = pd.to_numeric(df['Engine'], errors='coerce')
if df['Annual Income'].dtype == 'object':
    df['Annual Income'] = df['Annual Income'].replace('[\$,]', '', regex=True).astype(float)
df_cleaned = df[['Price ($)', 'Engine', 'Annual Income']].dropna()
correlation_matrix = df_cleaned.corr()
print(correlation_matrix)

#heatmap
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Between Car Price, Engine Size & Annual Income")
plt.show()
# Out:
#                Price ($)  Engine  Annual Income
# Price ($)            NaN     NaN            NaN
# Engine               NaN     NaN            NaN
# Annual Income        NaN     NaN            NaN

# %%
#whyyy this is not showing???????

# %%
#15. How does the average car price vary across different car models and engine types?
df['Price ($)'] = pd.to_numeric(df['Price ($)'], errors='coerce')
if df['Engine'].dtype == 'object':
    df['Engine'] = df['Engine'].str.extract('(\d+)')
df['Engine'] = pd.to_numeric(df['Engine'], errors='coerce')
avg_price = df.groupby(['Model', 'Engine'])['Price ($)'].mean().reset_index()
plt.figure(figsize=(12,6))
sns.barplot(x='Engine', y='Price ($)', hue='Model', data=avg_price, palette='viridis')
plt.xticks(rotation=90)
plt.title("Average Car Price Across Models & Engine Types")
plt.xlabel("Engine Size (CC)")
plt.ylabel("Average Price ($)")
plt.legend(title="Car Model", bbox_to_anchor=(1,1))
plt.show()

# %%
df.groupby(['Model', 'Engine'])['Price ($)'].mean().reset_index()

# Plot bar chart
plt.figure(figsize=(12,6))
sns.barplot(x='Engine', y='Price ($)', hue='Model', data=avg_price, palette='viridis')
plt.xticks(rotation=90)
plt.title("Average Car Price Across Models & Engine Types")
plt.xlabel("Engine Size (CC)")
plt.ylabel("Average Price ($)")
plt.legend(title="Car Model")
plt.show()

# %%
#explain this errors please!!!!!

# %% [markdown]
# # Spotify EDA

# %%
df = pd.read_csv('spotify.csv')

# %%
df
# Out:
#              Artist                                         Track Name  \
# 0             Drake            Rich Baby Daddy (feat. Sexyy Red & SZA)
# 1             Drake                                          One Dance
# 2             Drake                                 IDGAF (feat. Yeat)
# 3             Drake               First Person Shooter (feat. J. Cole)
# 4             Drake                      Jimmy Cooks (feat. 21 Savage)
# ..              ...                                                ...
# 435  French Montana                                    Splash Brothers
# 436         Fat Joe                     All The Way Up (feat. Infared)
# 437       A$AP Ferg  Work REMIX (feat. A$AP Rocky, French Montana, ...
# 438           Diddy                Another One Of Me (feat. 21 Savage)
# 439       Rick Ross                                       Stay Schemin
#
#      Popularity  Duration (ms)                Track ID
# 0            92         319191  1yeB8MUNeLo9Ek1UEpsyz6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Artist         440 non-null    object
#  1   Track Name     440 non-null    object
#  2   Popularity     440 non-null    int64
#  3   Duration (ms)  440 non-null    int64
#  4   Track ID       440 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 17.3+ KB

# %%
#1. Read the dataframe, check null value if present then do the needful, check duplicate row , if present then do the needful
df.isna().sum()
# Out:
# Artist           0
# Track Name       0
# Popularity       0
# Duration (ms)    0
# Track ID         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 27

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#2. What is the distribution of popularity among the tracks in the dataset? Visualize it using a histogram
plt.figure(figsize=(10,6))
sns.histplot(df['Popularity'],bins=20,kde=True)
plt.xlabel("popularity")
plt.ylabel("tracks")
plt.show()

# %%
#3. Is there any relationship between the popularity and the duration of tracks? Explore this using a scatter plot
plt.figure(figsize=(10,6))
sns.scatterplot(x='Popularity',y='Duration (ms)',data=df)
plt.xlabel('popularity')
plt.ylabel('duration (ms)')
plt.show()

# %%
#4. Which artist has the highest number of tracks in the dataset? Display the count of tracks for each artist using a countplot
plt.figure(figsize=(20,15))
sns.countplot(x='Artist',data=df)
plt.xlabel('artist')
plt.ylabel('tracks')
plt.xticks(rotation=90)
plt.show()

# %%
#5. What are the top 5 least popular tracks in the dataset? Provide the artist name and track name for each
df.sort_values(by='Popularity',ascending=True).head(5)
# Out:
#              Artist                     Track Name  Popularity  Duration (ms)  \
# 207          Pressa  Attachments (feat. Coi Leray)          29         171000
# 231   Justin Bieber                     Intentions          35         212853
# 413  French Montana                Splash Brothers          44         221863
# 225        Lil Baby                  On Me - Remix          47         135444
# 407     Wyclef Jean      911 (feat. Mary J. Blige)          48         259333
#
#                    Track ID
# 207  6EfJ8Ct3GHbBz2YlyPnMYb
# 231  7jAVt70Xdg8EwOtsFB1ZqK
# 413  3fBsEOnzwtlkpS0LxXAZhN
# 225  2uUFVnVFERNxUdcmvEs7LB
# 407  28hgx2bWXcaBJeC9zVwrBq

# %%
#6. Among the top 5 most popular artists, which artist has the highest popularity on average? Calculate and display the average popularity for each artist
df.groupby('Artist')['Popularity'].mean().sort_values(ascending=False).head(5)
# Out:
# Artist
# cassö           92.000000
# Trueno          89.000000
# David Guetta    87.000000
# Travis Scott    86.555556
# ¥$              85.100000
# Name: Popularity, dtype: float64

# %%
#7. For the top 5 most popular artists, what are their most popular tracks? List the track name for each artist
df.groupby('Track Name')['Popularity'].max().sort_values(ascending=False).head(5)
# Out:
# Track Name
# Lovin On Me                   97
# CARNIVAL                      96
# redrum                        96
# FE!N (feat. Playboi Carti)    93
# Prada                         92
# Name: Popularity, dtype: int64

# %%
#8. Visualize relationships between multiple numerical variables simultaneously using a pair plot
sns.pairplot(df)

# %%
#9.  Does the duration of tracks vary significantly across different artists? Explore this visually using a box plot or violin plot
plt.figure(figsize=(25,15))
sns.boxplot(x='Artist',y='Duration (ms)',data=df)
plt.xlabel('artist')
plt.ylabel('duration (ms)')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(25,15))
sns.violinplot(x='Artist',y='Duration (ms)',data=df)
plt.show()

# %%
#10.  How does the distribution of track popularity vary for different artists? Visualize this using a swarm plot or a violin plot
plt.figure(figsize=(25,15))
sns.swarmplot(x='Artist',y='Popularity',data=df)
plt.xlabel('artist')
plt.ylabel('popularity')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #Amazon Sales EDA

# %%
df = pd.read_csv("amazon.csv")

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1463 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1463 non-null   object
#  1   product_name         1463 non-null   object
#  2   category             1463 non-null   object
#  3   discounted_price     1463 non-null   object
#  4   actual_price         1463 non-null   object
#  5   discount_percentage  1463 non-null   object
#  6   rating               1463 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1463 non-null   object
#  9   user_id              1463 non-null   object
#  10  user_name            1463 non-null   object
#  11  review_id            1463 non-null   object
#  12  review_title         1463 non-null   object
#  13  review_content       1463 non-null   object
#  14  img_link             1463 non-null   object
# ...

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
columns_to_convert = ["discounted_price", "actual_price", "discount_percentage", "rating", "rating_count"]

def convert_to_numeric(column):
    return pd.to_numeric(column.str.replace(r"[^\d.]", "", regex=True), errors='coerce')

for col in columns_to_convert:
    df[col] = convert_to_numeric(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1463 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1463 non-null   object
#  1   product_name         1463 non-null   object
#  2   category             1463 non-null   object
#  3   discounted_price     1463 non-null   float64
#  4   actual_price         1463 non-null   float64
#  5   discount_percentage  1463 non-null   int64
#  6   rating               1462 non-null   float64
#  7   rating_count         1463 non-null   int64
#  8   about_product        1463 non-null   object
#  9   user_id              1463 non-null   object
#  10  user_name            1463 non-null   object
#  11  review_id            1463 non-null   object
#  12  review_title         1463 non-null   object
#  13  review_content       1463 non-null   object
#  14  img_link             1463 non-null   object
# ...

# %%
#1. What is the average rating for each product category?
df.groupby('category')['rating'].mean()
# Out:
# category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                    3.800000
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                   4.150000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                           3.500000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                        3.600000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                           4.050000
#                                                                                                                             ...
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens        4.250000
# ...

# %%
#2. What are the top rating_count products by category?
df.groupby('category')['rating_count'].max()
# Out:
# category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                     1118
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                    4426
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                            7222
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                        14969
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                            7352
#                                                                                                                           ...
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens         5792
# ...

# %%
#3. What is the distribution of discounted prices vs. actual prices?
plt.figure(figsize=(10,6))
sns.scatterplot(x='discounted_price',y='actual_price',data=df)
plt.show()

# %%
#4. How does the average discount percentage vary across categories
df.groupby("category")["discount_percentage"].mean().sort_values(ascending=False)
# Out:
# category
# Electronics|Mobiles&Accessories|MobileAccessories|Décor|PhoneCharms                                                 90.0
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|CableConnectionProtectors                          90.0
# Electronics|Headphones,Earbuds&Accessories|Earpads                                                                  90.0
# Electronics|Headphones,Earbuds&Accessories|Adapters                                                                 88.0
# Computers&Accessories|Accessories&Peripherals|Keyboards,Mice&InputDevices|Keyboard&MiceAccessories|DustCovers       87.5
#                                                                                                                     ...
# OfficeProducts|OfficeElectronics|Calculators|Basic                                                                   0.0
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|SmallApplianceParts&Accessories|StandMixerAccessories     0.0
# ...

# %%
#5. What are the most popular product names?
df.groupby('product_name')['rating_count'].max().sort_values(ascending=False).head(5)
# Out:
# product_name
# AmazonBasics Flexible Premium HDMI Cable (Black, 4K@60Hz, 18Gbps), 3-Foot              426973
# Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pack),Black                             426973
# Amazon Basics High-Speed HDMI Cable, 6 Feet - Supports Ethernet, 3D, 4K video,Black    426973
# boAt Bassheads 100 in Ear Wired Earphones with Mic(Taffy Pink)                         363713
# boAt Bassheads 100 in Ear Wired Earphones with Mic(Furious Red)                        363713
# Name: rating_count, dtype: int64

# %%
#6. What are the most popular product keywords?
df.groupby('product_id')['rating_count'].max().sort_values(ascending=False).head(5)
# Out:
# product_id
# B07KSMBL2H    426973
# B014I8SSD0    426973
# B014I8SX4Y    426973
# B07GPXXNNG    363713
# B07GQD4K6L    363713
# Name: rating_count, dtype: int64

# %%
#7. What are the most popular product reviews?
df.groupby('product_name')['rating_count'].max().sort_values(ascending=False).head(5)
# Out:
# product_name
# AmazonBasics Flexible Premium HDMI Cable (Black, 4K@60Hz, 18Gbps), 3-Foot              426973
# Amazon Basics High-Speed HDMI Cable, 6 Feet (2-Pack),Black                             426973
# Amazon Basics High-Speed HDMI Cable, 6 Feet - Supports Ethernet, 3D, 4K video,Black    426973
# boAt Bassheads 100 in Ear Wired Earphones with Mic(Taffy Pink)                         363713
# boAt Bassheads 100 in Ear Wired Earphones with Mic(Furious Red)                        363713
# Name: rating_count, dtype: int64

# %%
#8. What is the correlation between discounted_price and rating?
df['discounted_price'].corr(df['rating'])
# Out:
# 0.12113187526066266

# %%
#9. What are the Top 5 categories based on the highest rating?
df.groupby('category')['rating'].mean().sort_values(ascending=False).head(5)
# Out:
# category
# Computers&Accessories|Tablets                                               4.6
# Computers&Accessories|NetworkingDevices|NetworkAdapters|PowerLANAdapters    4.5
# Electronics|Cameras&Photography|Accessories|Film                            4.5
# Electronics|HomeAudio|MediaStreamingDevices|StreamingClients                4.5
# OfficeProducts|OfficeElectronics|Calculators|Basic                          4.5
# Name: rating, dtype: float64

# %%
#10. ' Identify any potential areas for improvement or optimization based on the data analysis?
#Product Discounts and Pricing Strategy
#Popular Product Listings
#Some products with high ratings (4.5+ stars) have low review counts.
